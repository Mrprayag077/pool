# %%
# !!pip install pandas
# !!pip install numpy
# Out:
# ['Requirement already satisfied: numpy in c:\\users\\admin$\\appdata\\local\\programs\\python\\python310\\lib\\site-packages (1.23.3)']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\ADMIN$\Desktop\pppppppp\PRACT-4 S FIRE\forestfires.csv", sep=',')

# %% [markdown]
# For more information, read [Cortez and Morais, 2007].
#
# X - x-axis spatial coordinate within the Montesinho park map: 1 to 9
# Y - y-axis spatial coordinate within the Montesinho park map: 2 to 9
# month - month of the year: 'jan' to 'dec'
# day - day of the week: 'mon' to 'sun'
# FFMC - FFMC index from the FWI system: 18.7 to 96.20
# DMC - DMC index from the FWI system: 1.1 to 291.3
# DC - DC index from the FWI system: 7.9 to 860.6
# ISI - ISI index from the FWI system: 0.0 to 56.10
# temp - temperature in Celsius degrees: 2.2 to 33.30
# RH - relative humidity in %: 15.0 to 100
# wind - wind speed in km/h: 0.40 to 9.40
# rain - outside rain in mm/m2 : 0.0 to 6.4
# area - the burned area of the forest (in ha): 0.00 to 1090.84
# (this output variable is very skewed towards 0.0, thus it may make
# sense to model with the logarithm transform).

# %%
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
df.describe()
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# ...

# %%
df.columns
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize':(8,8)})
sns.histplot(data=df, x="area", hue="rain",color="orange",binwidth=10,fill=True,edgecolor='red')
# Out:
# <AxesSubplot: xlabel='area', ylabel='Count'>

# %%
sns.displot(data=df, x="wind", kind="ecdf", rug=True)

# %%
#distribution plot
sns.displot(data=df, x="wind", hue="day",kind='kde', palette="Set2", rug= True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 #distribution plot
# ----> 2 sns.displot(data=df, x="wind", hue="day",kind='kde')
#
# NameError: name 'sns' is not defined

# %%
sns.boxplot(data=df, x="wind", y="month")
# Out:
# <AxesSubplot:xlabel='wind', ylabel='month'>

# %%
sns.set(rc={'figure.figsize':(8,8)})
sns.lineplot(y='wind', x='month', data=df)
# Out:
# <AxesSubplot: xlabel='month', ylabel='wind'>

# %%
sns.scatterplot( x='month',y='wind', data=df)
# Out:
# Text(0.5, 1.0, 'Wind Variation by Month')

# %%
plt.scatter(x=df["day"],y=df["wind"])
plt.title("DMC vs Area")
plt.xlabel("rain")
plt.ylabel("temp")
plt.show()

# %%
#sns.barplot( x='month',y='wind', data=df)
plt.bar(df['month'],df['wind'])
plt.xlabel('Page total likes')
plt.ylabel('Like')
plt.title('Scatter Plot: Page total likes vs Like')
plt.show()

# %%
plt.hist(df["wind"], bins=30, label='Histogram')
plt.xlabel('Page total likes')
plt.ylabel('Like')
plt.title('Histogram')
plt.legend()
plt.show()

# %%
# Define the columns to visualize
COLS = ['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
       'wind', 'rain']

# Set up the figure and axes wxh
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(12, 10))

# Plot the data
for col, ax in zip(COLS, axes.flatten()):
    sns.histplot(df[col], ax=ax)
    ax.set_title(col)

# Adjust the layout and spacing
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %%
df['burned'] = df['area'].apply(lambda x: 0.0 if x == 0.0 else 1.0)

# %%
plt.plot(df['rain'],ls = '-')

# %%
plt.xlabel('rain')
plt.subplot(1,2,1)
plt.plot(df['rain'],ls = '-')

plt.subplot(1,2,2)
plt.plot(df['rain'],ls = '-')

# %%
df1 = pd.read_csv(r"C:\Users\ADMIN$\Desktop\pppppppp\PRACT-4 S FIRE\heart.csv")

# %%
df1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
sns.set(rc={'figure.figsize':(8,8)})
sns.displot(x='age',data=df1)

# %%
sns.set(rc={'figure.figsize':(8,8)})
sns.displot(x='age',y='chol',data=df1,hue='sex', kind='hist',palette='Set2')

# %%
sns.barplot(x='sex',y='chol',data=df1)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='chol'>

# %%
sns.countplot(x='sex',data=df1)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
c_target=df1['restecg'].value_counts()
print(c_target)
# Out:
# 1    152
# 0    147
# 2      4
# Name: restecg, dtype: int64
